# %% [markdown]
# # Guided Project: Storytelling Data Visualization on Exchange Rates
#
# ### Author: Marwin M I B Carmo

# %% [markdown]
# ## Introduction
#
# The goal of this project is to practice data visualization skills. We will be using a dataset of Euro daily exchange rates between 1999 and 2021 available on [Kaggle](https://www.kaggle.com/lsind18/euro-exchange-daily-rates-19992020). For this project we are expected to focus on the exchange rate between the euro and the American dollar. However, because I am from Bazil, I will also work with the exchange rate with the Brazilian Real.

# %%
import pandas as pd

# reading dataset

exchange_rates = pd.read_csv('data/euro-daily-hist_1999_2021.csv')

# %%
# inspecting the first five rows
exchange_rates.head(5)
# Out:
#   Period\Unit: [Argentine peso ] [Australian dollar ] [Bulgarian lev ]  \
# 0   2021-09-20               NaN               1.6201           1.9558
# 1   2021-09-17               NaN               1.6111           1.9558
# 2   2021-09-16               NaN               1.6077           1.9558
# 3   2021-09-15               NaN               1.6153           1.9558
# 4   2021-09-14               NaN               1.6114           1.9558
#
#   [Brazilian real ] [Canadian dollar ] [Swiss franc ]  \
# 0            6.2495             1.5056         1.0883
# 1            6.2039             1.4913         1.0931
# 2            6.1611             1.4863         1.0886
# 3            6.1979             1.5004         1.0845
# 4            6.1788             1.4951         1.0887
#
#   [Chinese yuan renminbi ] [Cypriot pound ] [Czech koruna ]  ...  \
# 0                   7.5726              NaN          25.432  ...
# 1                   7.6044              NaN          25.296  ...
# ...

# %%
# inspecting the last five rows
exchange_rates.tail(5)
# Out:
#      Period\Unit: [Argentine peso ] [Australian dollar ] [Bulgarian lev ]  \
# 5873   1999-01-08               NaN               1.8406              NaN
# 5874   1999-01-07               NaN               1.8474              NaN
# 5875   1999-01-06               NaN               1.8820              NaN
# 5876   1999-01-05               NaN               1.8944              NaN
# 5877   1999-01-04               NaN               1.9100              NaN
#
#      [Brazilian real ] [Canadian dollar ] [Swiss franc ]  \
# 5873               NaN             1.7643         1.6138
# 5874               NaN             1.7602         1.6165
# 5875               NaN             1.7711         1.6116
# 5876               NaN             1.7965         1.6123
# 5877               NaN             1.8004         1.6168
#
#      [Chinese yuan renminbi ] [Cypriot pound ] [Czech koruna ]  ...  \
# 5873                      NaN          0.58187          34.938  ...
# ...

# %%
# getting info of the dataframe columns

exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5878 entries, 0 to 5877
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              5878 non-null   object
#  1   [Argentine peso ]         5383 non-null   object
#  2   [Australian dollar ]      5878 non-null   object
#  3   [Bulgarian lev ]          5476 non-null   object
#  4   [Brazilian real ]         5610 non-null   object
#  5   [Canadian dollar ]        5878 non-null   object
#  6   [Swiss franc ]            5878 non-null   object
#  7   [Chinese yuan renminbi ]  5610 non-null   object
#  8   [Cypriot pound ]          2346 non-null   object
#  9   [Czech koruna ]           5878 non-null   object
#  10  [Danish krone ]           5878 non-null   object
#  11  [Algerian dinar ]         5383 non-null   object
#  12  [Estonian kroon ]         3130 non-null   object
# ...

# %% [markdown]
# ## Data cleaning
#
# We can see that with the exception of the first columns, the whole dataset is composed of float numbers describing the exchange rate with the Euro. Before we start working on the visualization, we need to parse the columns stored as object to float.

# %%
# the following code was provided by Dataquest 
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                               '[Brazilian real ]': 'BR_real',
                               'Period\\Unit:': 'Time'},
                      inplace=True)
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)

# %%
euro_to_dollar = exchange_rates[['US_dollar', 'Time']]
euro_to_real = exchange_rates[['BR_real', 'Time']]

# %%
euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.3532     6
#           ..
# 1.0029     1
# 1.2797     1
# 1.0671     1
# 1.4288     1
# 1.0105     1
# Name: US_dollar, Length: 3576, dtype: int64

# %%
euro_to_real['BR_real'].value_counts()
# Out:
# -         61
# 3.0909     4
# 3.3277     4
# 2.7570     4
# 3.2395     4
#           ..
# 6.0777     1
# 3.2593     1
# 3.3918     1
# 2.5785     1
# 2.8060     1
# Name: BR_real, Length: 5027, dtype: int64

# %%
# dropping the rows with no real values, "-"
# converting from int to float

# eur_dollar
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != "-"]
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)

#eur_real
euro_to_real = euro_to_real[euro_to_real['BR_real'] != "-"]
euro_to_real['BR_real'] = euro_to_real['BR_real'].astype(float)

# %% [markdown]
# ## Rolling Mean
#
# Visualizing the evolution of the exchange rates for Dollar and Real

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style
# %matplotlib inline

plt.plot(euro_to_dollar['Time'],
         euro_to_dollar['US_dollar'])
plt.show()

# %%
plt.plot(euro_to_real['Time'],
         euro_to_real['BR_real'])
plt.show()

# %%
# creating a column for the rolling mean using a moving window of 30 days
euro_to_dollar['rolling_mean'] = euro_to_dollar['US_dollar'].rolling(30).mean()

# %%
# creating a column for the rolling mean using a moving window of 30 days
euro_to_real['rolling_mean'] = euro_to_real['BR_real'].rolling(30).mean()

# %% [markdown]
# ## What will be shown in those plots
#
# For the remaining of this project I'll focus on the exchange rate for the Euro-Real only.
#
# In 2016 president Dilma Rousseff was impeached from her position. There is a great debate about the legitimacy of the decision of the senate. Since the early days when president Jair Bolsonaro took charge in 2018 the country has been suffering from an ongoing financial crisis. To make matters worse, Bolsonaro has taken successive bad decisions in handling the effects of the COVID-19 pandemic, which has aggraveted the economic crisis.
#
# I plan to explore how the value of brazilian currency, Real, got affected by all this events, starting from the first mandate of ex-president Rouseff and finishing in the current days.

# %%
# subsetting data from 2010
start_time = euro_to_real[euro_to_real['Time'] >= "2010-01-01" ]['Time']
rolling_mean = euro_to_real[euro_to_real['Time'] >= "2010-01-01" ]['rolling_mean']

style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(15,6))

# entire series
ax.plot(start_time, rolling_mean, color='#af0b1e', alpha=0.1)

# Dilma presidency
ax.plot(euro_to_real[(euro_to_real['Time'] >= "2010-01-01") & (euro_to_real['Time'] <= "2016-08-31")]['Time'],
        euro_to_real[(euro_to_real['Time'] >= "2010-01-01") & (euro_to_real['Time'] <= "2016-08-31")]['rolling_mean'],
        color='#af0b1e')

# Michael Temer presidency (vice-president assuming after Dilma has been expelled from the charge)
ax.plot(euro_to_real[(euro_to_real['Time'] > "2016-08-31") & (euro_to_real['Time'] < "2018-01-01")]['Time'],
        euro_to_real[(euro_to_real['Time'] > "2016-08-31") & (euro_to_real['Time'] < "2018-01-01")]['rolling_mean'],
        color='#6D6D6D', alpha = .5)

# Jair Bolsonaro elected 
ax.plot(euro_to_real[(euro_to_real['Time'] >= "2018-01-01") & (euro_to_real['Time'] < "2020-03-01")]['Time'],
        euro_to_real[(euro_to_real['Time'] >= "2018-01-01") & (euro_to_real['Time'] < "2020-03-01")]['rolling_mean'],
        color='#005DFF')

# Brasilia, Brazil's capital, starts lockdown mandate due to COVID-19 outbreak
ax.plot(euro_to_real[(euro_to_real['Time'] >= "2020-03-01")]['Time'],
        euro_to_real[(euro_to_real['Time'] >= "2020-03-01")]['rolling_mean'],
        color='#005DFF')

# Dilma deposed from charge
ax.axvline(17050.0, linestyle = 'dashed', c = '#af0b1e')
ax.text(16560, 6.1, '     Dilma\n impeached', c = '#af0b1e', size = 14, weight='bold')

# Bolsonaro gets elected
ax.axvline(17530.0, linestyle = 'dashed', color='#005DFF')
ax.text(17570, 6.1, 'Bolsonaro\n  elected', c = '#005DFF', size = 14, weight='bold')

# COVID-19 outbreak
ax.axvline(18320.0, linestyle = 'dashed', color='#26A700')
ax.text(18420, 4.1, 'COVID-19\n outbreak', c = '#26A700', size = 14, weight='bold')

# Title
ax.text(14425.0, 7.40, "Euro-BRL rate reaches its highest in 11 years during Bolsonaro's administraton",
        weight='bold', size=18)
# Subtitle
ax.text(14425.0, 7.10, "Euro-BRL exchange rates between 2010 and 2021", size=16)


plt.yticks([3,4,5,6], labels=['R$3.00', 'R$4.00', 'R$5.00', 'R$6.00'])


plt.show()
